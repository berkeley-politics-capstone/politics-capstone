# %%
from bs4 import BeautifulSoup
import requests

# %%
headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'}
url = "https://www.homedepot.com/b/Appliances-Dishwashers/LG-Electronics/Samsung/N-5yc1vZc3poZ21jZa0f?NCNI-5"
page = requests.get(url, timeout=10, headers=headers)

# %%
bob = BeautifulSoup(page.text, "html.parser")

# %%
a = str(bob.head.find('script', type='application/ld+json'))
a = a[a.find('{'):-1*a[::-1].find('}') ]

# %%
a
# Out:
# '{\n          "@type":"WebPage",\n          "name":"Samsung - LG Electronics - Dishwashers - Appliances - The Home Depot",\n          "url":"https://www.homedepot.com/b/Appliances-Dishwashers/LG-Electronics/Samsung/N-5yc1vZc3poZ21jZa0f?NCNI-5",\n          "breadcrumb":{\n            "@type":"BreadcrumbList",\n            "itemListElement":[\n                {\n                  "@type":"ListItem",\n                  "position":5,\n                  "item":{\n                    "name":"Samsung",\n                    "@id":"https://www.homedepot.com/b/Appliances-Dishwashers/LG-Electronics/N-5yc1vZc3poZ21j"\n                  }\n                },\n                {\n                  "@type":"ListItem",\n                  "position":4,\n                  "item":{\n                    "name":"LG Electronics",\n                    "@id":"https://www.homedepot.com/b/Appliances-Dishwashers/Samsung/N-5yc1vZc3poZa0f"\n                  }\n                },\n                {\n             
# ...
