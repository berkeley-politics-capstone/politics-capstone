# %% [markdown]
# # Endorsements Dataset
# Download data from [https://github.com/fivethirtyeight/data/tree/master/endorsements](https://github.com/fivethirtyeight/data/tree/master/endorsements) and place in `"../data/"`

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv(os.path.join("..","data","endorsements","endorsements-2020.csv"))
df.head()
# Out:
#          date        position city state          endorser       endorsee  \
# 0  2017-07-28  representative  NaN    MD       David Trone   John Delaney
# 1  2019-01-02        governor  NaN    NY      Andrew Cuomo      Joe Biden
# 2  2019-01-03         senator  NaN    CA  Dianne Feinstein      Joe Biden
# 3  2019-01-08         senator  NaN    DE  Thomas R. Carper      Joe Biden
# 4  2019-01-12  representative  NaN    TX    Joaquin Castro  Julian Castro
#
#   endorser party                                             source  order  \
# 0              D  https://twitter.com/davidjtrone/status/8909859...    NaN
# 1              D  https://www.cnn.com/2019/01/02/politics/cuomo-...    NaN
# 2              D  https://www.politico.com/story/2019/01/03/dian...    NaN
# 3              D  https://fox61.com/2019/01/08/will-he-or-wont-h...    NaN
# 4              D  https://www.dallasnews.com/news/politics/2019/...    NaN
#
#           category body  district  points
# ...

# %%
results = df.groupby(by=["endorsee","position"])["date"].count()
results
# Out:
# endorsee            position
# Amy Klobuchar       governor                                 1
#                     lieutenant governor                      1
#                     mayor                                    1
#                     past vice president                      1
#                     representative                           2
#                     senator                                  1
#                     speaker                                  1
#                     state auditor                            1
# Bernie Sanders      DNC member                               5
#                     lieutenant governor                      1
#                     mayor                                    1
#                     representative                           2
#                     senator                                  1
# Beto O'Rourke       DNC member                               1
# ...
