# %% [markdown]
# # Google and Facebook Spend
#
# Both [Google](https://transparencyreport.google.com/political-ads/region/US) and [Facebook](https://www.facebook.com/ads/library/report/) publish reports on political advertising for the goal of increasing transparency.
#
# [Bully Pulpit Media](https://bpimedia.com/) uses this data to publish a weekly metric report called the [2020 Campaign Tracker](https://2020campaigntracker.com/). This site reports each candidate's weekly spend by both Facebook and Google platforms.
#
# I've downloaded a CSV file of the 2020 Campaign Tracker, which has already cleaned up the data before visualizing it (in particular, they map the fund/PAC name that is used in Google and Facebook to the candidate). This file was last updated **July 1, 2019.**

# %%
# Libraries

import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Bringing in the CSV file

df = pd.read_csv('2020_Digital_Spend.csv')

# %%
df
# Out:
#     Date of Week End            Candidate  Platform   Spend
# 0           1/5/2019         Donald Trump  Facebook  401993
# 1           1/5/2019         Donald Trump    Google  175000
# 2           1/5/2019     Elizabeth Warren  Facebook   52574
# 3           1/5/2019          Andrew Yang  Facebook     230
# 4          1/12/2019         Donald Trump    Google  837100
# 5          1/12/2019         Donald Trump  Facebook  726572
# 6          1/12/2019     Elizabeth Warren  Facebook   27612
# 7          1/12/2019     Elizabeth Warren    Google   10600
# 8          1/12/2019        Tulsi Gabbard    Google    4700
# 9          1/12/2019         John Delaney  Facebook    4223
# 10         1/12/2019        Tulsi Gabbard  Facebook     437
# 11         1/12/2019          Andrew Yang  Facebook     233
# 12         1/19/2019         Donald Trump  Facebook  561208
# 13         1/19/2019         Donald Trump    Google  330600
# 14         1/19/2019   Kirsten Gillibrand  Facebook   61794
# 15         1/19/2019   Kirsten Gillibrand    Google   35200
# 16         1/19/2019        Tulsi Gabbard  Facebook   24603
# 17         1/19/2019     Elizabeth Warren  Facebook   21383
# 18         1/19/2019        Tulsi Gabbard    Google   17100
# 19         1/19/2019     Elizabeth Warren    Google   16300
# 20         1/19/2019         John Delaney  Facebook    2623
# 21         1/26/2019        Kamala Harris  Facebook  194383
# 22         1/26/2019         Donald Trump  Facebook  103784
# 23         1/26/2019        Kamala Harris    Google   94400
# 24         1/26/2019         Donald Trump    Google   87300
# 25         1/26/2019        Tulsi Gabbard  Facebook   28425
# 26         1/26/2019   Kirsten Gillibrand  Facebook   27957
# 27         1/26/2019        Tulsi Gabbard    Google   23100
# 28         1/26/2019     Elizabeth Warren  Facebook   22729
# 29         1/26/2019     Elizabeth Warren    Google   20400
# ..               ...                  ...       ...     ...
# 719        6/22/2019          Cory Booker    Google   45500
# 720        6/22/2019        Eric Swalwell  Facebook   43198
# 721        6/22/2019  Marianne Williamson  Facebook   37870
# 722        6/22/2019        Beto O'Rourke  Facebook   37851
# 723        6/22/2019       Bernie Sanders    Google   36600
# 724        6/22/2019            Joe Biden    Google   33100
# 725        6/22/2019       Michael Bennet  Facebook   32482
# 726        6/22/2019        Kamala Harris    Google   31700
# 727        6/22/2019        Steve Bullock  Facebook   28220
# 728        6/22/2019        Beto O'Rourke    Google   25200
# 729        6/22/2019          Mike Gravel  Facebook   20970
# 730        6/22/2019           Jay Inslee    Google   17400
# 731        6/22/2019        Eric Swalwell    Google   15400
# 732        6/22/2019        Tulsi Gabbard    Google   14200
# 733        6/22/2019       Michael Bennet    Google   13300
# 734        6/22/2019        Amy Klobuchar    Google   13200
# 735        6/22/2019   Kirsten Gillibrand    Google   11900
# 736        6/22/2019    John Hickenlooper  Facebook   11037
# 737        6/22/2019        Kamala Harris  Facebook    8571
# 738        6/22/2019         Seth Moulton    Google    8300
# 739        6/22/2019         John Delaney  Facebook    8164
# 740        6/22/2019             Tim Ryan    Google    6800
# 741        6/22/2019    John Hickenlooper    Google    6000
# 742        6/22/2019       Bill de Blasio  Facebook    3682
# 743        6/22/2019       Bill de Blasio    Google    2100
# 744        6/22/2019        Tulsi Gabbard  Facebook    1704
# 745        6/22/2019        Julián Castro    Google    1400
# 746        6/22/2019             Tim Ryan  Facebook    1399
# 747        6/22/2019  Marianne Williamson    Google     600
# 748        6/22/2019          Mike Gravel    Google     100
#
# [749 rows x 4 columns]

# %%
# Reproducing the chart that 2020 Campaign Tracker does

df.groupby(['Candidate', 'Platform'])['Spend'].sum().unstack('Platform').fillna(0).plot(kind='bar', stacked=True)
