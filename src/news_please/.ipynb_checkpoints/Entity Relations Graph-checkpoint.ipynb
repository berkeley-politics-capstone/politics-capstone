# %%
import json
import ast
import pandas as pd
from urllib.parse import urlparse
import numpy as np
from urllib.parse import urlparse
import nltk
nltk.download('punkt')

from tqdm._tqdm_notebook import tqdm_notebook as tqdm
tqdm.pandas()


DATA_DIRECTORY = '../../data/reddit/Article_data_2019/'
candidates = [ "TRUMP", "SANDERS","DELANEY","WARREN","HARRIS","GILLIBRAND","O'ROURKE","KLOBUCHAR","BOOKER",
    "BUTTIGIEG","GABBARD","YANG","INSLEE","HICKENLOOPER","WILLIAMSON","DE LA FUENTE","CASTRO","BIDEN"]
candidates = set([x.lower() for x in candidates])
# Out:
# [nltk_data] Downloading package punkt to /Users/kippy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# The following ceel is for converting old formats to the new format in pandas (as opposed to csvs). This cell can be skipped if you have a pandas pkl with article text in it already.

# %%
## load the data into a dataframe, spit out the row of an error if any
df2 = pd.read_pickle(DATA_DIRECTORY + 'reddit_2019_06_15.pkl')
list_df = []
i = 0
for row in open(DATA_DIRECTORY + "/article_data.csv", 'r').readlines():
    url, data = row.split(', ', 1)
    try:
        data = ast.literal_eval(data)
        list_df.append((url, data))
    except Exception as e:
        print(i, e)    
    i += 1 
df = pd.merge(df2, pd.DataFrame(list_df, columns = ['url', 'article_data']), on='url', how='left', )

# %%
df.to_pickle(DATA_DIRECTORY + 'reddit_2019_06_15_with_article_text.pkl')

# %%
PICKLE_NAME = DATA_DIRECTORY + ""
df = pd.read_pickle(PICKLE_NAME)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# IsADirectoryError: [Errno 21] Is a directory: '../../data/reddit/Article_data_2019/'
#
# During handling of the above exception, another exception occurred:
#
# IsADirectoryError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     172                 return read_wrapper(
# --> 173                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     174             # compat pickle
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# IsADirectoryError: [Errno 21] Is a directory: '../../data/reddit/Article_data_2019/'
#
# During handling of the above exception, another exception occurred:
#
# IsADirectoryError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#     178     try:
# --> 179         return try_read(path)
#     180     except Exception:  # noqa: E722
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     176                 return read_wrapper(
# --> 177                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     178     try:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# IsADirectoryError: [Errno 21] Is a directory: '../../data/reddit/Article_data_2019/'
#
# During handling of the above exception, another exception occurred:
#
# IsADirectoryError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     165                 warnings.simplefilter("ignore", Warning)
# --> 166                 return read_wrapper(lambda f: pkl.load(f))
#     167         except Exception:  # noqa: E722
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# IsADirectoryError: [Errno 21] Is a directory: '../../data/reddit/Article_data_2019/'
#
# During handling of the above exception, another exception occurred:
#
# IsADirectoryError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     172                 return read_wrapper(
# --> 173                     lambda f: pc.load(f, encoding=encoding, compat=False))
#     174             # compat pickle
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#
# /usr/local/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#
# IsADirectoryError: [Errno 21] Is a directory: '../../data/reddit/Article_data_2019/'
#
# During handling of the above exception, another exception occurred:
#
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-111-7dde3caaab0c> in <module>
#       1 PICKLE_NAME = DATA_DIRECTORY + ""
# ----> 2 df = pd.read_pickle(PICKLE_NAME)
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(path, compression)
#     180     except Exception:  # noqa: E722
#     181         if PY3:
# --> 182             return try_read(path, encoding='latin1')
#     183         raise
#     184
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in try_read(path, encoding)
#     175             except Exception:  # noqa: E722
#     176                 return read_wrapper(
# --> 177                     lambda f: pc.load(f, encoding=encoding, compat=True))
#     178     try:
#     179         return try_read(path)
#
# /usr/local/lib/python3.7/site-packages/pandas/io/pickle.py in read_wrapper(func)
#     144         f, fh = _get_handle(path, 'rb',
#     145                             compression=compression,
# --> 146                             is_text=False)
#     147         try:
#     148             return func(f)
#
# /usr/local/lib/python3.7/site-packages/pandas/io/common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     428         else:
#     429             # Python 3 and binary mode
# --> 430             f = open(path_or_buf, mode)
#     431         handles.append(f)
#     432
#
# IsADirectoryError: [Errno 21] Is a directory: '../../data/reddit/Article_data_2019/'

# %%
clean_df = pd.concat( [df.drop(['article_data'],axis=1), df['article_data'].progress_apply(pd.Series)]
                      ,axis = 1)
clean_df.drop(0, axis = 1, inplace=True)


def df_column_uniquify(df):
    df_columns = df.columns
    new_columns = []
    for item in df_columns:
        counter = 0
        newitem = item
        while newitem in new_columns:
            counter += 1
            newitem = "{}_{}".format(item, counter)
        new_columns.append(newitem)
    df.columns = new_columns
    return df

clean_df = df_column_uniquify(clean_df)
# Out:
# HBox(children=(IntProgress(value=0, max=121986), HTML(value='')))

# %%
# How many are valid?
clean_df[(~clean_df['title_1'].isnull()) & (~clean_df['text'].isnull())].shape[0], clean_df.shape[0]
# Out:
# (82018, 121986)

# %%
clean_df = clean_df[(~clean_df['title_1'].isnull()) & (~clean_df['text'].isnull())]
clean_df["title_tokenized"] = clean_df.progress_apply(lambda x: [token.lower() for token in nltk.word_tokenize(x.title)]
                                                      , axis = 1)
clean_df["text_tokenized"] = clean_df.progress_apply(lambda x: [token.lower() for token in nltk.word_tokenize(x.text)]
                                                     , axis = 1)
clean_df["domain"] = clean_df.progress_apply(lambda x: urlparse(x.url).netloc, axis = 1)
clean_df['candidate_title'] = clean_df.progress_apply(lambda x: candidates.intersection(x.title_tokenized), axis=1)
clean_df['candidate_text'] = clean_df.progress_apply(lambda x: candidates.intersection(x.text_tokenized), axis=1)
# Out:
# HBox(children=(IntProgress(value=0, max=82018), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=82018), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=82018), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=82018), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=82018), HTML(value='')))

# %%
clean_df.memory_usage(deep=True).agg('sum')
# Out:
# 1893446375

# %%
clean_df[clean_df['candidate_text'] == set(('castro', 'trump')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-121-2878e1f708af> in <module>
# ----> 1 clean_df[clean_df['candidate_text'] == set('castro', 'trump')]
#
# TypeError: set expected at most 1 arguments, got 2

# %%
candidate_counts_title = {}
for item in clean_df.apply(lambda x: tuple(x.candidate_title), axis=1):
    candidate_counts_title[item] = candidate_counts_title.get(item, 0) + 1
candidate_counts_title
# Out:
# {(): 44350,
#  ('warren',): 1013,
#  ('trump', 'warren'): 165,
#  ('sanders',): 2227,
#  ('trump',): 27227,
#  ('castro', 'trump'): 17,
#  ('trump', 'sanders'): 381,
#  ('inslee',): 200,
#  ('biden',): 2006,
#  ('klobuchar', 'warren'): 5,
#  ('klobuchar',): 138,
#  ('harris',): 615,
#  ('sanders', 'warren'): 83,
#  ("o'rourke",): 390,
#  ('trump', 'biden'): 389,
#  ('booker',): 185,
#  ('gabbard',): 222,
#  ('castro',): 86,
#  ('trump', "o'rourke"): 83,
#  ('trump', 'harris'): 79,
#  ('trump', 'sanders', 'biden'): 42,
#  ('yang',): 275,
#  ('harris', 'booker'): 13,
#  ('klobuchar', 'trump'): 20,
#  ('gillibrand',): 130,
#  ('gabbard', 'sanders', 'warren'): 3,
#  ('trump', 'gabbard'): 23,
#  ('trump', 'booker'): 25,
#  ('harris', 'warren'): 8,
#  ('buttigieg',): 765,
#  ('williamson',): 11,
#  ('hickenlooper',): 29,
#  ('gabbard', 'sanders'): 13,
#  ('trump', 'harris', 'biden'): 4,
#  ('harris', 'biden'): 22,
#  ('delaney',): 30,
#  ('harris', 'warren', 'biden'): 6,
#  ('gillibrand', 'harris', 'booker'): 1,
#  ('warren', 'harris', 'booker'): 1,
#  ('harris', 'sanders', 'warren'): 1,
#  ('trump', 'buttigieg'): 147,
#  ('sanders', 'biden'): 196,
#  ('warren', 'booker'): 2,
#  ('gillibrand', 'trump'): 19,
#  ('klobuchar', "o'rourke"): 2,
#  ('sanders', 'harris'): 19,
#  ('sanders', 'harris', 'warren'): 5,
#  ('klobuchar', 'biden'): 9,
#  ('gabbard', 'yang'): 2,
#  ('castro', 'sanders'): 5,
#  ('klobuchar', 'harris'): 1,
#  ('buttigieg', 'sanders'): 21,
#  ("o'rourke", 'trump', 'sanders', 'biden'): 1,
#  ('trump', "o'rourke", 'sanders', 'biden'): 4,
#  ('gabbard', 'buttigieg', 'delaney'): 3,
#  ('sanders', 'harris', 'biden'): 4,
#  ('trump', 'warren', 'biden'): 3,
#  ('gillibrand', 'trump', 'warren'): 1,
#  ('trump', 'hickenlooper'): 4,
#  ('trump', 'yang'): 35,
#  ('warren', 'biden'): 31,
#  ('gillibrand', "o'rourke"): 2,
#  ("o'rourke", 'sanders'): 41,
#  ('klobuchar', 'buttigieg'): 1,
#  ('warren', 'harris', 'sanders', 'biden', "o'rourke"): 3,
#  ("o'rourke", 'buttigieg'): 5,
#  ('trump', 'sanders', 'warren', 'biden'): 5,
#  ('harris', 'gillibrand', 'warren'): 1,
#  ('harris', 'buttigieg', 'warren'): 1,
#  ("o'rourke", 'sanders', 'biden'): 8,
#  ('harris', 'sanders', 'warren', 'booker'): 1,
#  ('sanders', 'hickenlooper'): 1,
#  ('castro', "o'rourke", 'harris'): 1,
#  ("o'rourke", 'biden'): 2,
#  ("o'rourke", 'harris'): 1,
#  ("o'rourke", 'warren'): 3,
#  ('gillibrand', 'trump', 'sanders'): 1,
#  ('trump', 'inslee'): 6,
#  ('trump', "o'rourke", 'harris'): 1,
#  ("o'rourke", 'sanders', 'yang', 'biden'): 1,
#  ('castro', 'warren', 'biden'): 2,
#  ('buttigieg', 'biden'): 12,
#  ('sanders', 'warren', 'biden'): 23,
#  ('gillibrand', 'biden'): 2,
#  ('buttigieg', 'harris', 'sanders', 'biden'): 1,
#  ('castro', "o'rourke"): 1,
#  ('sanders', 'yang'): 1,
#  ('castro', 'biden'): 2,
#  ('harris', 'warren', 'buttigieg', 'sanders', 'biden', 'booker'): 3,
#  ('gillibrand', 'warren', 'harris', 'sanders', 'booker'): 1,
#  ('buttigieg', 'sanders', 'biden'): 7,
#  ('yang',
#   'castro',
#   'gabbard',
#   'harris',
#   'warren',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('klobuchar', 'sanders'): 2,
#  ('gillibrand', 'buttigieg'): 3,
#  ('inslee', 'yang', 'delaney'): 1,
#  ('williamson', 'warren', 'yang', 'biden'): 1,
#  ('gabbard', 'harris'): 1,
#  ('sanders', 'williamson', 'yang'): 1,
#  ('trump', 'buttigieg', 'sanders'): 7,
#  ('buttigieg', 'warren', 'biden'): 1,
#  ('buttigieg', 'trump', 'sanders', 'biden'): 1,
#  ('buttigieg', 'trump', 'sanders'): 2,
#  ('buttigieg', 'trump', 'sanders', 'warren'): 2,
#  ('trump', 'harris', 'warren'): 1,
#  ('buttigieg', 'warren'): 2,
#  ('trump', 'delaney'): 1,
#  ('buttigieg', 'booker'): 4,
#  ('sanders', 'delaney'): 1,
#  ('buttigieg', 'harris', 'warren'): 1,
#  ('booker', 'biden'): 5,
#  ('sanders', 'booker'): 1,
#  ('harris', 'gillibrand', 'warren', 'booker'): 1,
#  ('trump', "o'rourke", 'warren'): 1,
#  ('buttigieg', "o'rourke"): 9,
#  ('harris', 'warren', 'buttigieg', 'sanders', 'biden', "o'rourke"): 1,
#  ('harris', 'warren', 'buttigieg', 'sanders', 'biden'): 2,
#  ('inslee', 'sanders'): 1,
#  ('buttigieg', 'harris'): 2,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'booker'): 1,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   "o'rourke",
#   'booker'): 1,
#  ('harris', 'buttigieg', 'warren', 'biden'): 1,
#  ('trump', 'warren', 'booker'): 2,
#  ('trump', "o'rourke", 'warren', 'biden'): 1,
#  ('trump', 'sanders', 'warren'): 1,
#  ('gillibrand', 'booker'): 1,
#  ('inslee', 'biden'): 3,
#  ('warren', 'harris', 'trump', 'buttigieg', 'sanders', 'biden', "o'rourke"): 1,
#  ('klobuchar', 'harris', 'warren', 'biden', 'booker'): 1,
#  ('trump', 'gabbard', 'sanders'): 1,
#  ('harris',
#   'warren',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ("o'rourke", 'hickenlooper'): 1,
#  ('harris', 'warren', 'buttigieg', 'biden', 'booker'): 5,
#  ('yang', 'biden'): 1,
#  ('castro', 'harris', 'biden'): 1,
#  ('trump', 'harris', 'warren', 'biden'): 1,
#  ('buttigieg', 'sanders', 'warren', 'biden'): 1}

# %%
candidate_counts_text = {}
for item in clean_df.apply(lambda x: tuple(x.candidate_text), axis=1):
    candidate_counts_text[item] = candidate_counts_text.get(item, 0) + 1
candidate_counts_text
# Out:
# {(): 20931,
#  ('sanders', 'warren'): 145,
#  ('trump', 'sanders'): 3038,
#  ('klobuchar', 'sanders'): 6,
#  ('trump', 'sanders', 'warren', 'biden'): 222,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 12,
#  ('trump', 'sanders', 'warren'): 368,
#  ('sanders',): 1022,
#  ('buttigieg', 'trump', 'sanders', 'biden'): 58,
#  ('trump',): 40037,
#  ('harris',): 460,
#  ('trump', 'buttigieg'): 288,
#  ('inslee', 'sanders', 'warren', 'booker'): 4,
#  ('trump', 'warren'): 947,
#  ('gillibrand', 'trump', 'warren'): 28,
#  ('trump', 'buttigieg', 'warren', 'biden'): 26,
#  ('warren',): 551,
#  ('castro', 'trump'): 293,
#  ('inslee', 'harris', 'warren', 'trump', 'booker'): 5,
#  ('klobuchar', 'gillibrand', 'warren', 'trump', 'sanders', "o'rourke"): 7,
#  ('trump', 'booker'): 111,
#  ('inslee', 'harris', 'warren', 'trump', 'sanders', 'booker'): 4,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 4,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden'): 12,
#  ('trump', 'biden'): 1579,
#  ('trump', 'yang'): 182,
#  ('biden',): 704,
#  ('klobuchar', 'warren', 'trump', 'buttigieg', 'biden'): 3,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('inslee', 'warren', 'booker'): 1,
#  ('trump', 'inslee'): 104,
#  ('castro', 'warren', 'trump', 'buttigieg', 'biden'): 1,
#  ('castro',
#   'gabbard',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 2,
#  ('trump', 'sanders', 'booker'): 29,
#  ('trump', 'buttigieg', 'biden'): 76,
#  ('gillibrand', 'trump'): 131,
#  ('gillibrand', 'harris', 'warren', 'trump', 'sanders', 'biden', 'booker'): 26,
#  ('klobuchar', 'warren', 'trump', 'sanders', 'biden'): 22,
#  ('trump', 'sanders', 'biden'): 657,
#  ('yang',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'williamson',
#   'booker'): 71,
#  ('trump', 'harris'): 558,
#  ("o'rourke", 'sanders', 'warren', 'biden'): 2,
#  ('castro', 'warren', 'trump', 'sanders', 'delaney'): 1,
#  ('klobuchar', 'castro', 'inslee', 'warren', 'trump'): 1,
#  ('trump', 'warren', 'booker'): 22,
#  ('williamson',): 38,
#  ('sanders', 'biden'): 206,
#  ('gillibrand', 'harris', 'warren', 'sanders', 'biden', 'booker'): 3,
#  ('harris', 'klobuchar', 'trump', 'warren'): 4,
#  ('harris', 'trump', 'sanders', 'warren'): 47,
#  ('gillibrand', 'harris', 'warren', 'sanders', "o'rourke", 'booker'): 3,
#  ('harris', 'warren', 'trump', 'sanders', 'biden'): 93,
#  ('harris', 'warren', 'sanders', 'biden', 'booker'): 10,
#  ('trump', "o'rourke"): 219,
#  ('harris', 'warren', 'trump', 'sanders', 'biden', 'booker'): 20,
#  ('castro',): 106,
#  ("o'rourke",): 197,
#  ('booker',): 136,
#  ('trump', 'delaney'): 50,
#  ('castro', 'warren', 'harris', 'trump', 'sanders', 'biden'): 3,
#  ('harris', 'booker'): 43,
#  ('buttigieg', 'trump', "o'rourke", 'biden'): 22,
#  ('klobuchar', 'gillibrand', 'harris', 'warren', 'trump'): 6,
#  ('sanders', 'warren', 'booker'): 13,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden'): 4,
#  ("o'rourke", 'gillibrand', 'trump', 'sanders'): 12,
#  ('warren', 'harris', 'trump', 'biden', 'booker'): 12,
#  ('trump', 'gabbard', 'sanders'): 67,
#  ('gillibrand', 'harris', 'warren', 'trump', 'sanders', 'booker'): 30,
#  ('warren', 'harris', 'sanders', 'biden', 'booker'): 7,
#  ('trump', 'sanders', 'harris', 'warren'): 48,
#  ('klobuchar', 'gillibrand', 'harris', 'warren', 'trump', 'sanders'): 1,
#  ('trump', 'warren', 'biden'): 118,
#  ('castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden'): 6,
#  ('trump', 'gabbard'): 80,
#  ('warren', 'trump', 'sanders', 'biden', "o'rourke", 'booker'): 2,
#  ('trump', "o'rourke", 'warren', 'sanders'): 3,
#  ('harris', 'warren', 'trump', 'sanders', 'biden', "o'rourke", 'booker'): 9,
#  ('trump', 'williamson', 'warren'): 3,
#  ('trump', "o'rourke", 'biden'): 20,
#  ('castro', 'trump', 'sanders'): 25,
#  ('harris', 'warren', 'trump', 'sanders', 'booker'): 16,
#  ('buttigieg',): 270,
#  ("o'rourke", 'sanders', 'biden'): 12,
#  ('harris', 'warren'): 31,
#  ('trump', 'sanders', 'warren', 'booker'): 23,
#  ('trump', 'sanders', 'harris', 'booker'): 39,
#  ('castro',
#   'klobuchar',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 2,
#  ('gabbard', 'harris'): 2,
#  ('castro', 'harris', 'warren', 'trump', 'booker'): 5,
#  ('harris', 'warren', 'trump', 'sanders', 'biden', "o'rourke"): 18,
#  ('trump', 'sanders', 'harris'): 118,
#  ('trump', 'harris', 'warren', 'biden'): 14,
#  ('williamson', 'warren', 'sanders', 'biden'): 1,
#  ('inslee', 'sanders'): 8,
#  ('klobuchar',): 80,
#  ('gillibrand', 'sanders', 'warren', 'booker'): 2,
#  ('klobuchar', 'trump'): 138,
#  ('trump', 'hickenlooper'): 27,
#  ('trump', 'buttigieg', 'harris', 'biden'): 15,
#  ('trump', 'gabbard', 'harris'): 6,
#  ('warren', 'harris', 'trump', 'buttigieg', 'sanders', 'biden', 'booker'): 9,
#  ('gabbard',): 92,
#  ('trump', 'harris', 'warren'): 31,
#  ('klobuchar', 'warren', 'harris', 'trump', 'biden', 'booker'): 1,
#  ('klobuchar', 'trump', 'sanders', 'warren'): 9,
#  ('buttigieg', 'harris', 'biden'): 4,
#  ('klobuchar', 'warren', 'trump'): 2,
#  ('sanders', 'harris', 'warren', 'biden'): 14,
#  ('sanders', 'harris'): 110,
#  ('inslee', 'trump', 'buttigieg', 'sanders', 'biden'): 2,
#  ('harris', 'warren', 'booker'): 4,
#  ('buttigieg', 'warren', 'sanders', 'biden'): 10,
#  ('gillibrand', 'harris', 'trump', 'sanders', 'biden', 'booker'): 7,
#  ('klobuchar', 'harris', 'trump', 'buttigieg', 'biden'): 7,
#  ('castro', 'warren'): 4,
#  ('yang',): 116,
#  ('trump', 'williamson', 'sanders'): 4,
#  ('harris', 'trump', 'buttigieg', 'sanders', 'biden', "o'rourke", 'booker'): 3,
#  ('klobuchar', 'gillibrand', 'harris', 'warren', 'trump', 'biden'): 1,
#  ('klobuchar', 'gillibrand', 'trump', 'buttigieg', 'biden'): 1,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 4,
#  ('castro', 'harris', 'warren', 'trump', "o'rourke"): 1,
#  ('klobuchar', 'harris', 'warren', 'trump', 'sanders'): 12,
#  ('gillibrand', 'trump', 'harris', 'booker'): 10,
#  ('delaney',): 9,
#  ('klobuchar', 'harris', 'trump', 'sanders', 'biden', 'booker'): 7,
#  ('trump', 'sanders', 'warren', 'williamson'): 14,
#  ('castro', 'warren', 'harris', 'trump', 'sanders', 'biden', 'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'booker'): 17,
#  ('warren', 'biden'): 27,
#  ('gillibrand', 'warren', 'harris', 'trump', 'booker'): 6,
#  ('castro', 'harris', 'warren'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'biden',
#   'sanders',
#   'delaney',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar', 'booker', 'trump'): 1,
#  ('buttigieg', 'sanders', 'biden'): 44,
#  ('trump', 'harris', 'booker'): 62,
#  ('gabbard', 'sanders'): 22,
#  ('warren', 'harris', 'trump', 'sanders', 'biden', 'booker'): 12,
#  ('klobuchar', 'trump', 'harris', 'biden'): 3,
#  ('klobuchar', 'trump', 'buttigieg', 'sanders', 'biden', 'booker'): 1,
#  ('gillibrand', 'warren'): 5,
#  ('castro', 'harris', 'warren', 'trump', 'sanders', "o'rourke", 'booker'): 1,
#  ('castro', 'warren', 'trump', 'delaney', "o'rourke", 'booker'): 1,
#  ('gillibrand', 'trump', 'yang'): 2,
#  ('gillibrand', 'harris', 'warren', 'biden', 'booker'): 1,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('castro',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('trump', 'inslee', 'sanders'): 8,
#  ('trump', "o'rourke", 'harris', 'warren'): 2,
#  ('gabbard', 'gillibrand', 'harris', 'warren', 'trump', 'sanders'): 1,
#  ('trump', 'inslee', 'delaney', 'biden'): 2,
#  ('castro', 'gabbard', 'warren', 'trump', 'sanders', 'biden', 'delaney'): 4,
#  ('inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'hickenlooper',
#   'booker'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 5,
#  ('castro',
#   'gabbard',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'delaney'): 1,
#  ('castro', 'gabbard', 'warren', 'trump', 'sanders'): 2,
#  ('castro', 'gabbard', 'warren', 'trump', 'sanders', 'biden'): 2,
#  ('trump', 'gabbard', 'sanders', 'warren'): 37,
#  ('castro',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('castro',
#   'gabbard',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 4,
#  ('castro',
#   'inslee',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker',
#   'delaney'): 1,
#  ('castro', 'trump', 'hickenlooper'): 3,
#  ('castro', 'gabbard', 'harris', 'warren', 'trump', 'sanders', 'booker'): 4,
#  ('gabbard', 'sanders', 'harris'): 3,
#  ('klobuchar',
#   'castro',
#   'gabbard',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('castro', 'gabbard', 'harris', 'warren', 'trump'): 1,
#  ('castro', "o'rourke", 'trump'): 8,
#  ('castro', 'gillibrand', 'harris', 'warren', 'sanders', 'biden', 'booker'): 6,
#  ('gabbard', 'warren', 'trump', 'sanders', 'booker'): 1,
#  ('gabbard', 'harris', 'trump', 'buttigieg', 'sanders', 'biden'): 3,
#  ('castro', 'gabbard', 'warren', 'trump', 'delaney', 'biden', 'booker'): 4,
#  ('castro',
#   'gabbard',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'biden',
#   "o'rourke"): 1,
#  ('castro', "o'rourke"): 8,
#  ('castro', 'gabbard', 'warren', 'harris', 'trump', 'delaney'): 1,
#  ('castro', 'gabbard', 'warren', 'trump', 'buttigieg', 'biden'): 1,
#  ('trump', 'delaney', 'biden'): 1,
#  ('castro', 'gabbard', 'harris', 'warren', 'sanders'): 1,
#  ('yang', 'biden'): 7,
#  ('inslee',): 139,
#  ('trump', "o'rourke", 'sanders'): 29,
#  ('trump', "o'rourke", 'warren'): 12,
#  ('gabbard', 'gillibrand', 'harris', 'warren', 'booker'): 1,
#  ('klobuchar', 'trump', 'harris', 'booker'): 11,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'booker'): 9,
#  ('castro', 'harris'): 3,
#  ('gabbard', 'harris', 'warren', 'trump', 'sanders'): 11,
#  ('castro', 'gillibrand', 'harris', 'trump', 'sanders'): 4,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'trump',
#   'sanders',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar', 'harris', 'trump', 'buttigieg', 'biden', 'booker'): 5,
#  ('warren', 'trump', 'buttigieg', 'sanders', 'biden'): 96,
#  ('gillibrand',): 59,
#  ('klobuchar', 'trump', 'buttigieg', 'biden'): 2,
#  ('yang',
#   'klobuchar',
#   'inslee',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'williamson',
#   'booker'): 31,
#  ('klobuchar', 'gillibrand', 'harris', 'warren', 'trump', 'booker'): 8,
#  ('gillibrand', 'trump', 'sanders', 'biden'): 9,
#  ('castro', 'gabbard', 'warren', 'trump', 'sanders', 'biden', "o'rourke"): 2,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'biden',
#   'sanders',
#   'delaney',
#   'booker'): 3,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 32,
#  ('gillibrand', 'gabbard', "o'rourke", 'warren'): 1,
#  ('castro',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney'): 1,
#  ('booker', 'harris', 'warren'): 14,
#  ('castro', 'trump', 'harris'): 3,
#  ('castro', 'klobuchar', 'trump'): 7,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'sanders',
#   'booker',
#   'delaney'): 1,
#  ('hickenlooper',): 21,
#  ('harris', 'sanders', 'warren'): 8,
#  ('gillibrand', 'harris', 'warren', 'trump', 'biden', "o'rourke"): 1,
#  ('sanders', 'yang'): 3,
#  ('klobuchar',
#   'inslee',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   "o'rourke"): 1,
#  ('castro', 'gillibrand', 'harris', 'warren', 'trump', 'delaney'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   "o'rourke",
#   'booker'): 1,
#  ('gabbard', 'gillibrand', 'warren', 'trump', 'sanders', 'biden'): 1,
#  ('gabbard', 'warren', 'trump', 'sanders', 'biden', 'booker'): 2,
#  ('harris', 'biden'): 35,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 4,
#  ('gillibrand', 'warren', 'harris', 'trump', 'sanders', 'biden', 'booker'): 17,
#  ('gabbard', 'gillibrand', 'harris', 'warren', 'trump'): 30,
#  ('gillibrand', 'trump', 'harris', 'warren'): 13,
#  ('castro',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 9,
#  ('harris', 'trump', 'sanders', 'biden', 'booker'): 22,
#  ('castro', 'gillibrand', 'harris', 'warren', 'trump'): 8,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'delaney',
#   'booker'): 2,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   "o'rourke",
#   'booker'): 1,
#  ('castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker',
#   'delaney'): 1,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 3,
#  ('castro', 'gabbard', 'warren', 'harris', 'sanders', 'biden'): 1,
#  ('gillibrand', 'harris', 'booker'): 4,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('sanders', 'harris', 'biden'): 28,
#  ('inslee', 'harris', 'trump', 'buttigieg', 'biden', 'booker', 'delaney'): 1,
#  ('castro', 'gabbard', 'gillibrand', 'harris', 'warren', 'delaney'): 1,
#  ('yang',
#   'castro',
#   'gabbard',
#   'inslee',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'williamson',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   "o'rourke",
#   'booker'): 7,
#  ('trump', 'inslee', 'warren', 'booker'): 1,
#  ('warren', 'harris', 'trump', 'sanders', "o'rourke", 'booker'): 3,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'delaney'): 1,
#  ('gillibrand', 'buttigieg', 'harris', 'warren'): 5,
#  ('gillibrand', 'harris', 'warren', 'trump', 'buttigieg', 'biden'): 4,
#  ('castro', 'gabbard', 'gillibrand', 'harris', 'warren', 'trump'): 1,
#  ('castro', 'gabbard', 'gillibrand', 'harris', 'warren'): 1,
#  ('sanders', 'booker'): 15,
#  ('klobuchar', 'harris', 'trump'): 5,
#  ('inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 2,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('gillibrand', 'harris', 'warren', 'trump', 'sanders'): 25,
#  ('gillibrand', 'trump', 'harris'): 10,
#  ('gillibrand', 'harris'): 4,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'biden'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker',
#   'delaney'): 1,
#  ('castro', 'gillibrand', 'harris', 'warren', 'trump', 'sanders', 'booker'): 4,
#  ('gillibrand', 'gabbard', 'harris', 'warren'): 1,
#  ('gillibrand', 'harris', 'sanders', 'biden', 'booker'): 2,
#  ('trump', 'harris', 'biden'): 62,
#  ('gillibrand', 'warren', 'trump', 'sanders', 'biden', 'booker'): 6,
#  ('castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 5,
#  ('gillibrand', 'trump', 'buttigieg', 'sanders', 'biden'): 4,
#  ('trump', 'sanders', 'harris', 'biden'): 65,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden'): 3,
#  ('gillibrand', 'sanders', 'harris', 'warren'): 7,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 23,
#  ('harris', 'warren', 'biden'): 8,
#  ('gabbard', 'gillibrand', 'harris', 'sanders', 'biden'): 1,
#  ('harris', 'trump', 'warren'): 34,
#  ('castro',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('warren', 'harris', 'trump', 'sanders', 'booker'): 17,
#  ('biden', 'klobuchar', 'harris', 'trump'): 1,
#  ('castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'biden'): 2,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden'): 2,
#  ('trump', 'williamson'): 30,
#  ('castro', 'harris', 'warren', 'trump', 'sanders', 'biden'): 5,
#  ('klobuchar',
#   'inslee',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'booker',
#   'williamson',
#   'yang'): 1,
#  ('castro', 'harris', 'warren', 'trump', 'hickenlooper', 'biden'): 1,
#  ('klobuchar', 'warren', 'trump', 'sanders', 'booker', 'delaney'): 3,
#  ('castro', 'gillibrand', 'warren', 'sanders', 'biden'): 2,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('harris', 'warren', 'trump', 'biden', 'delaney'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'buttigieg',
#   "o'rourke"): 1,
#  ('harris', 'trump', 'gabbard', 'warren'): 1,
#  ('castro', 'gabbard', 'harris', 'warren', 'sanders', 'booker'): 1,
#  ('gabbard', 'harris', 'warren', 'trump', 'sanders', 'biden'): 10,
#  ('trump', 'gabbard', "o'rourke", 'harris'): 1,
#  ('gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 2,
#  ('klobuchar', 'trump', 'harris'): 5,
#  ('yang',
#   'castro',
#   'gabbard',
#   'inslee',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('trump', 'harris', 'delaney'): 3,
#  ('harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 8,
#  ('trump', 'williamson', 'harris'): 6,
#  ('trump', "o'rourke", 'harris'): 5,
#  ('harris', 'trump', 'warren', 'biden'): 22,
#  ('yang',
#   'klobuchar',
#   'inslee',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'williamson',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('castro', 'harris', 'warren', 'trump', 'sanders', 'buttigieg'): 1,
#  ('gabbard', 'harris', 'sanders', 'biden', 'booker'): 1,
#  ('castro', 'klobuchar', 'buttigieg', 'sanders', 'biden'): 1,
#  ('gillibrand', 'harris', 'warren', 'trump', 'booker'): 9,
#  ('harris', 'gillibrand', 'trump', 'warren'): 6,
#  ('castro',
#   'inslee',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'delaney',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker',
#   'williamson',
#   'yang'): 1,
#  ('gabbard', 'gillibrand', 'harris', 'warren', 'sanders', 'biden'): 5,
#  ('yang',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney'): 1,
#  ('gillibrand', 'harris', 'warren', 'trump', 'sanders', 'biden'): 9,
#  ('gillibrand', 'harris', 'warren'): 8,
#  ('trump', 'gabbard', 'harris', 'warren'): 1,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 8,
#  ('trump', 'buttigieg', 'harris'): 3,
#  ('klobuchar', 'harris', 'booker'): 2,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker',
#   'delaney'): 3,
#  ('castro', 'trump', 'gabbard', 'harris'): 2,
#  ('harris', 'warren', 'trump', 'hickenlooper', 'biden'): 2,
#  ('harris', 'warren', 'buttigieg', 'sanders', 'biden'): 29,
#  ('harris', 'trump', 'castro', 'warren'): 7,
#  ('trump', 'sanders', 'yang', 'biden'): 4,
#  ('castro', 'harris', 'sanders', 'biden', 'booker'): 2,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('castro', 'buttigieg', 'yang'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 2,
#  ('castro',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'booker'): 2,
#  ('castro', 'trump', 'sanders', 'warren'): 5,
#  ('gillibrand',
#   'harris',
#   'trump',
#   'delaney',
#   'hickenlooper',
#   'biden',
#   'booker'): 3,
#  ('klobuchar', 'gillibrand', 'harris', 'warren', 'sanders', 'booker'): 13,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 4,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 2,
#  ('sanders', 'harris', 'warren'): 21,
#  ('inslee', 'harris'): 9,
#  ('williamson', 'harris'): 4,
#  ('gillibrand', 'trump', 'gabbard', 'harris'): 1,
#  ('klobuchar',
#   'inslee',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   "o'rourke",
#   'booker'): 1,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('warren', 'sanders', 'harris', 'booker'): 25,
#  ('castro', 'gabbard', 'warren', 'trump', 'buttigieg', 'biden', 'delaney'): 1,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('gabbard', 'harris', 'warren', 'trump', 'buttigieg', 'biden', 'booker'): 1,
#  ('castro', 'gillibrand', 'harris', 'warren', 'sanders'): 1,
#  ('gillibrand', 'warren', 'harris', 'booker'): 5,
#  ('gillibrand', 'castro', 'sanders', 'harris'): 1,
#  ('gabbard', 'gillibrand', 'harris', 'trump', 'biden'): 1,
#  ("o'rourke", 'trump', 'sanders', 'biden'): 8,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 6,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'biden',
#   "o'rourke"): 1,
#  ('gillibrand', 'trump', "o'rourke"): 2,
#  ('klobuchar', 'harris', 'warren', 'trump', 'sanders', 'biden'): 50,
#  ('harris', 'sanders', 'warren', 'biden'): 19,
#  ('gillibrand', 'warren', 'trump', 'sanders', 'booker'): 10,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'biden',
#   'booker'): 5,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'biden',
#   'booker'): 16,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'booker'): 1,
#  ('gillibrand', 'warren', 'harris', 'trump', 'sanders', 'booker'): 14,
#  ('harris', 'trump', 'warren', 'booker'): 7,
#  ('klobuchar', 'trump', 'booker'): 4,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'booker'): 1,
#  ('castro', 'gabbard', 'gillibrand', 'warren', 'harris', 'trump', 'booker'): 1,
#  ('trump', 'sanders', 'williamson'): 5,
#  ('klobuchar', 'gillibrand', 'warren', 'harris', 'booker'): 4,
#  ('gabbard', 'gillibrand', 'warren', 'harris', 'trump', 'booker'): 2,
#  ('gillibrand', 'sanders', 'booker'): 4,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 6,
#  ('gabbard', 'gillibrand', 'warren', 'harris', 'booker'): 2,
#  ('buttigieg', 'booker', 'biden'): 1,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'delaney',
#   'booker'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   "o'rourke"): 1,
#  ('gabbard', 'harris', 'warren', 'trump', 'sanders', 'biden', "o'rourke"): 4,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'biden',
#   'williamson'): 1,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('harris', 'booker', 'biden'): 14,
#  ('trump', 'gabbard', 'sanders', 'booker'): 4,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('gabbard', 'warren', 'harris', 'trump', 'booker'): 1,
#  ('gillibrand', 'harris', 'warren', 'sanders', 'booker'): 22,
#  ('castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'buttigieg',
#   'delaney',
#   'booker'): 2,
#  ('gillibrand', 'castro', 'harris', 'warren'): 1,
#  ('gillibrand', 'trump', 'sanders', 'warren'): 15,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'biden',
#   'booker'): 1,
#  ('yang',
#   'klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('castro',
#   'gabbard',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 1,
#  ('harris',
#   'williamson',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'yang'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ("o'rourke", 'castro', 'sanders', 'warren'): 2,
#  ('castro',
#   'inslee',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('delaney', 'biden'): 2,
#  ('castro', 'gillibrand', 'harris', 'biden', 'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'delaney',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('castro', 'gillibrand', 'harris', 'trump', 'delaney', 'biden', 'booker'): 1,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'hickenlooper',
#   "o'rourke",
#   'booker'): 1,
#  ('trump', 'buttigieg', 'booker', 'biden'): 2,
#  ('castro',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('castro', 'gillibrand', 'harris', 'hickenlooper', 'biden', 'booker'): 1,
#  ('klobuchar', 'harris', 'trump', 'biden', "o'rourke"): 1,
#  ('castro', 'klobuchar', 'harris', 'trump', 'biden'): 2,
#  ('inslee', 'gillibrand', 'warren', 'harris', 'sanders', 'booker'): 1,
#  ('klobuchar', 'trump', 'warren', 'biden'): 3,
#  ('castro', 'gillibrand', 'warren', 'harris', 'trump'): 1,
#  ('gillibrand', 'trump', 'sanders', 'biden', 'booker'): 1,
#  ('trump', 'warren', 'harris', 'booker'): 7,
#  ('gillibrand', 'trump', 'sanders', 'booker'): 3,
#  ('castro', 'gillibrand', 'harris', 'warren', 'trump', 'booker'): 2,
#  ('castro', 'buttigieg', 'booker'): 1,
#  ('booker', 'sanders', 'harris', 'warren'): 6,
#  ('castro', 'trump', "o'rourke"): 7,
#  ('harris', 'trump', 'buttigieg', 'warren'): 3,
#  ('warren', 'booker'): 5,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'biden',
#   'booker'): 1,
#  ('klobuchar', 'harris', 'warren', 'trump', 'sanders', 'biden', 'booker'): 5,
#  ('gillibrand', 'trump', 'buttigieg', 'biden'): 15,
#  ("o'rourke", 'sanders', 'warren'): 2,
#  ('warren', 'harris', 'trump', 'buttigieg', 'biden', 'booker'): 1,
#  ('klobuchar', "o'rourke", 'trump'): 5,
#  ('klobuchar', 'harris'): 3,
#  ('gillibrand', 'trump', 'buttigieg', 'biden', 'booker'): 1,
#  ('gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'biden',
#   'booker'): 2,
#  ('gillibrand', 'booker'): 5,
#  ('yang',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'trump',
#   'buttigieg',
#   "o'rourke",
#   'delaney'): 1,
#  ('castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'sanders',
#   'hickenlooper',
#   'booker'): 1,
#  ('gillibrand', 'warren', 'booker'): 2,
#  ('gillibrand', 'castro', 'warren', 'booker'): 1,
#  ('klobuchar', 'warren', 'trump', 'buttigieg', 'booker'): 6,
#  ('gabbard', 'booker'): 4,
#  ('trump', 'buttigieg', 'warren'): 33,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   "o'rourke",
#   'booker'): 3,
#  ('trump', 'gabbard', 'harris', 'booker'): 1,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('trump', "o'rourke", 'harris', 'booker'): 2,
#  ('klobuchar', 'biden'): 14,
#  ('gillibrand', 'sanders', 'harris', 'booker'): 3,
#  ('castro', 'gillibrand', 'harris', 'warren', 'sanders', 'booker'): 5,
#  ('klobuchar', 'harris', 'warren', 'trump', 'sanders', 'booker'): 3,
#  ('klobuchar', 'harris', 'warren', 'trump', 'biden'): 3,
#  ('yang',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'williamson',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'biden',
#   'booker'): 4,
#  ('castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   "o'rourke",
#   'booker'): 3,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar', 'warren', 'harris', 'booker'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'biden'): 1,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'harris',
#   'warren',
#   'williamson',
#   'booker'): 1,
#  ('sanders', 'warren', 'williamson'): 4,
#  ('gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'biden'): 3,
#  ('castro', 'gillibrand', 'harris', 'warren', 'trump', 'sanders'): 17,
#  ('castro',
#   'gabbard',
#   'klobuchar',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 16,
#  ('inslee', 'harris', 'trump', 'biden', 'buttigieg', 'delaney', 'booker'): 1,
#  ('klobuchar', 'sanders', 'trump'): 8,
#  ('warren', 'harris', 'booker'): 3,
#  ('castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'booker'): 7,
#  ('harris', 'warren', 'trump', 'sanders', 'buttigieg', 'biden', 'booker'): 23,
#  ('yang',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'williamson',
#   'booker'): 3,
#  ('klobuchar', 'biden', 'warren', 'trump'): 3,
#  ('sanders', 'harris', 'booker', 'biden'): 9,
#  ('gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('klobuchar',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'booker'): 1,
#  ('gillibrand', 'klobuchar', 'harris', 'trump'): 1,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('klobuchar', 'harris', 'warren', 'trump', 'booker'): 7,
#  ('castro',
#   'gabbard',
#   'klobuchar',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'delaney',
#   'booker'): 1,
#  ('trump', 'buttigieg', 'sanders', 'biden'): 39,
#  ('klobuchar', 'gabbard', 'gillibrand', 'harris', 'warren', 'trump'): 2,
#  ('klobuchar', 'harris', 'biden'): 2,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'trump',
#   'biden',
#   'booker'): 1,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'williamson'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker',
#   'williamson',
#   'yang'): 1,
#  ('klobuchar',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'booker'): 4,
#  ('yang',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'williamson',
#   'booker'): 2,
#  ('gillibrand', 'harris', 'trump', 'sanders', 'booker'): 7,
#  ('trump', 'buttigieg', 'sanders'): 52,
#  ('trump', 'booker', 'harris', 'warren'): 3,
#  ('gabbard', 'gillibrand', 'warren', 'trump', 'booker'): 2,
#  ('sanders', 'trump', 'buttigieg', 'yang'): 1,
#  ("o'rourke", 'trump', 'sanders'): 31,
#  ('klobuchar', 'gillibrand', 'warren', 'trump', 'sanders', 'booker'): 2,
#  ('yang',
#   'klobuchar',
#   'castro',
#   'gabbard',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'williamson',
#   'booker'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'biden',
#   'booker'): 2,
#  ('klobuchar', 'trump', 'biden'): 5,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'delaney',
#   'booker'): 3,
#  ('harris', 'gillibrand', 'warren', 'booker'): 8,
#  ('klobuchar', 'gillibrand', 'harris', 'warren', 'booker'): 2,
#  ('klobuchar', 'gillibrand', 'warren', 'harris', 'trump', 'booker'): 3,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('klobuchar', 'gabbard', 'gillibrand', 'harris', 'warren', 'williamson'): 1,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('trump', 'warren', 'yang'): 11,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('klobuchar', 'sanders', 'warren'): 7,
#  ('klobuchar',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 2,
#  ('klobuchar', 'gabbard', 'harris', 'warren', 'trump', 'sanders'): 2,
#  ('warren', 'harris', 'trump', 'sanders', "o'rourke"): 3,
#  ('castro', 'warren', 'harris', 'sanders', 'booker'): 1,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'booker'): 1,
#  ('klobuchar', 'trump', 'sanders'): 7,
#  ('warren', 'harris', 'hickenlooper', 'trump'): 1,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke"): 1,
#  ('klobuchar', 'harris', 'warren'): 1,
#  ('yang',
#   'castro',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'williamson',
#   'booker'): 1,
#  ('klobuchar', 'warren'): 4,
#  ('gillibrand', 'warren', 'trump', 'buttigieg', 'biden'): 5,
#  ('klobuchar', 'gillibrand', 'harris', 'trump', 'sanders', 'booker'): 1,
#  ('sanders', 'harris', 'booker'): 12,
#  ('gillibrand', 'warren', 'harris', 'sanders', 'booker'): 13,
#  ('trump', 'yang', 'biden'): 22,
#  ('trump', 'williamson', 'yang'): 3,
#  ('klobuchar', 'trump', 'sanders', 'biden'): 10,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('trump', 'biden', 'sanders', 'delaney', 'booker'): 4,
#  ('klobuchar', "o'rourke"): 10,
#  ('klobuchar', 'warren', 'booker', 'trump'): 3,
#  ('klobuchar', 'trump', 'warren', 'booker'): 1,
#  ('yang',
#   'castro',
#   'klobuchar',
#   'gabbard',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('gabbard', 'harris', 'warren', 'sanders', 'biden', 'booker'): 2,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 6,
#  ('gillibrand', 'trump', "o'rourke", 'biden'): 1,
#  ('trump', 'inslee', 'delaney'): 6,
#  ('castro', 'gillibrand', 'warren', 'trump', 'sanders', 'booker'): 1,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 4,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'booker'): 1,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('warren', 'trump', 'sanders', 'biden', 'booker'): 7,
#  ('klobuchar',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 2,
#  ('yang',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'delaney',
#   'williamson',
#   'booker'): 4,
#  ('klobuchar',
#   'gabbard',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 3,
#  ('gabbard', 'harris', 'warren', 'trump', 'sanders', 'booker'): 12,
#  ('klobuchar', 'trump', 'sanders', 'harris'): 3,
#  ('klobuchar', 'inslee', 'harris', 'warren', 'sanders', 'biden', 'booker'): 2,
#  ('klobuchar', 'warren', 'harris', 'sanders', 'buttigieg', 'booker'): 4,
#  ('harris', 'trump', 'sanders', "o'rourke", 'booker'): 2,
#  ('castro', 'sanders', 'trump'): 6,
#  ('gabbard', 'harris', 'warren', 'sanders', "o'rourke", 'booker'): 2,
#  ('gillibrand', 'klobuchar', 'sanders', 'warren'): 3,
#  ('klobuchar', 'harris', 'warren', 'sanders', 'biden', 'booker'): 4,
#  ('trump', 'klobuchar', 'sanders', 'biden'): 3,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'biden',
#   'sanders',
#   'buttigieg',
#   'delaney',
#   'booker'): 1,
#  ('klobuchar', 'harris', 'sanders', 'biden', 'booker'): 2,
#  ('klobuchar', 'trump', 'sanders', 'biden', 'delaney'): 1,
#  ('trump', 'harris', 'booker', 'biden'): 13,
#  ('trump', "o'rourke", 'warren', 'biden'): 6,
#  ('castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'delaney'): 1,
#  ('yang',
#   'klobuchar',
#   'gabbard',
#   'castro',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'williamson',
#   'booker'): 1,
#  ('gabbard', 'sanders', 'biden'): 19,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ("o'rourke", 'klobuchar', 'sanders', 'trump'): 1,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'harris',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 2,
#  ('yang',
#   'klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'biden',
#   'booker'): 6,
#  ('sanders', "o'rourke", 'harris', 'warren'): 1,
#  ('castro', 'trump', 'biden'): 3,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'delaney'): 1,
#  ('klobuchar', 'harris', 'trump', 'sanders', 'biden'): 10,
#  ('klobuchar', 'sanders', 'harris'): 4,
#  ('trump', 'sanders', 'buttigieg', 'biden', 'delaney'): 1,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 4,
#  ('klobuchar', 'sanders', 'harris', 'warren'): 2,
#  ('castro', 'gillibrand', 'harris', 'trump', 'sanders', 'delaney'): 1,
#  ('klobuchar', 'warren', 'harris', 'trump', 'sanders', 'biden', 'booker'): 3,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'booker'): 1,
#  ('klobuchar', 'harris', 'warren', 'sanders', 'biden'): 1,
#  ('gillibrand',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('buttigieg', 'klobuchar', 'sanders', 'booker'): 1,
#  ('klobuchar', 'warren', 'harris', 'sanders', 'biden', 'booker'): 1,
#  ('yang',
#   'castro',
#   'gabbard',
#   'klobuchar',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'williamson',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   "o'rourke",
#   'booker'): 4,
#  ('castro',
#   'gabbard',
#   'klobuchar',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 1,
#  ('booker', "o'rourke", 'harris', 'warren'): 2,
#  ('klobuchar', 'warren', 'harris', 'hickenlooper', 'biden', 'booker'): 1,
#  ('yang',
#   'klobuchar',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ("o'rourke", 'harris', 'biden'): 2,
#  ('klobuchar', 'gillibrand', 'warren', 'sanders', 'biden'): 1,
#  ('castro', 'trump', 'warren'): 30,
#  ('gillibrand', 'gabbard', 'harris'): 2,
#  ('castro', 'gillibrand', 'warren', 'trump', 'sanders', 'biden'): 3,
#  ('klobuchar', 'harris', 'warren', 'buttigieg', 'biden', 'booker'): 1,
#  ('gillibrand', 'sanders'): 15,
#  ('castro', 'trump', "o'rourke", 'biden'): 2,
#  ('buttigieg', 'harris', 'booker', 'biden'): 9,
#  ('klobuchar', 'harris', 'trump', 'sanders', 'booker'): 2,
#  ('gillibrand', 'trump', 'sanders', 'harris'): 2,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'biden'): 1,
#  ('klobuchar',
#   'gabbard',
#   'inslee',
#   'castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('gabbard', 'harris', 'warren', 'sanders', 'biden'): 4,
#  ('castro', 'sanders'): 16,
#  ('trump', 'warren', 'booker', 'biden'): 1,
#  ('klobuchar', 'sanders', 'biden'): 1,
#  ('gillibrand', 'klobuchar', 'trump'): 3,
#  ('gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden'): 2,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 2,
#  ('klobuchar',
#   'inslee',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden'): 1,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('klobuchar', 'harris', 'warren', 'trump', 'sanders', "o'rourke"): 1,
#  ('gillibrand', 'buttigieg', 'delaney'): 6,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'warren',
#   'harris',
#   'sanders',
#   'buttigieg',
#   'booker'): 1,
#  ('castro', 'klobuchar', 'harris', 'warren', 'sanders'): 1,
#  ('harris', 'klobuchar', 'sanders', 'warren'): 4,
#  ('warren', 'harris', 'trump', 'buttigieg', 'sanders'): 1,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'biden',
#   'sanders',
#   'delaney',
#   'williamson',
#   'booker'): 1,
#  ('castro', 'klobuchar', 'harris', 'warren', 'trump', 'sanders', 'biden'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'delaney',
#   'booker'): 1,
#  ('inslee', 'warren', 'harris', 'trump', 'sanders', 'delaney', 'booker'): 1,
#  ('klobuchar', 'warren', 'trump', 'sanders', 'booker'): 7,
#  ('harris', 'trump', 'buttigieg', 'sanders', 'biden', 'booker'): 3,
#  ('harris', 'castro', 'warren', 'biden'): 1,
#  ('klobuchar', 'gillibrand', 'warren', 'harris', 'sanders', 'booker'): 5,
#  ('harris', 'gillibrand', "o'rourke", 'warren'): 1,
#  ('gillibrand', 'trump', 'sanders'): 15,
#  ('castro', 'harris', 'warren', 'trump', 'sanders'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke"): 1,
#  ('harris', 'warren', 'booker', 'biden'): 1,
#  ('buttigieg', 'biden'): 18,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden'): 1,
#  ('gillibrand', 'harris', 'trump', 'buttigieg', 'biden', 'booker'): 1,
#  ('castro',
#   'gabbard',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'williamson'): 1,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 1,
#  ("o'rourke", 'sanders', 'harris', 'warren'): 1,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 3,
#  ('warren', 'trump', 'buttigieg', 'sanders', 'booker'): 1,
#  ('harris', 'gillibrand', 'sanders', 'warren'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 4,
#  ('klobuchar',
#   'castro',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'booker'): 1,
#  ('warren', 'yang'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   "o'rourke",
#   'booker'): 1,
#  ('castro', 'klobuchar', 'harris', 'sanders', 'biden', 'booker'): 1,
#  ('harris', 'warren', 'trump', 'sanders', "o'rourke", 'booker'): 2,
#  ('hickenlooper', 'sanders', 'delaney', 'trump'): 5,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 3,
#  ('gillibrand', 'yang'): 4,
#  ('harris', 'sanders', 'warren', 'yang'): 4,
#  ('klobuchar', 'warren', 'harris', 'trump', 'sanders', 'booker'): 2,
#  ('castro', 'harris', 'warren', 'trump', 'buttigieg', 'sanders', 'booker'): 1,
#  ('inslee', 'sanders', 'harris', 'warren'): 1,
#  ('warren', 'trump', 'sanders', 'buttigieg', 'biden', 'booker'): 1,
#  ('harris', 'castro', 'sanders', 'warren'): 5,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden'): 1,
#  ('harris', 'warren', 'trump', 'hickenlooper', 'biden', 'booker'): 2,
#  ('klobuchar', 'sanders', 'harris', 'biden'): 4,
#  ('sanders', 'delaney'): 6,
#  ('klobuchar', 'sanders', 'harris', 'trump'): 2,
#  ('buttigieg', 'sanders'): 24,
#  ('gillibrand', 'booker', 'harris', 'warren'): 1,
#  ('castro', 'trump', 'harris', 'booker'): 1,
#  ('warren', 'trump', 'sanders', 'biden', 'yang'): 5,
#  ('castro', 'harris', 'warren', 'trump', 'biden', 'williamson'): 2,
#  ('castro', 'sanders', 'harris', 'warren'): 1,
#  ('klobuchar', 'trump', 'harris', 'warren'): 1,
#  ('trump', "o'rourke", 'booker', 'biden'): 1,
#  ('klobuchar', 'harris', 'warren', 'trump', 'sanders', 'biden', "o'rourke"): 9,
#  ('trump', "o'rourke", 'sanders', 'biden'): 8,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('castro', 'harris', 'warren', 'trump', 'sanders', 'biden', "o'rourke"): 2,
#  ('gillibrand', 'warren', 'sanders', 'biden', 'booker'): 1,
#  ('castro', 'trump', 'sanders', 'biden', "o'rourke"): 5,
#  ('gabbard', 'buttigieg', 'delaney'): 6,
#  ('trump', 'inslee', 'sanders', 'warren'): 2,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'booker'): 7,
#  ('klobuchar', 'warren', 'harris', 'trump', 'sanders', 'biden', "o'rourke"): 3,
#  ('castro',
#   'inslee',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden'): 2,
#  ('trump', 'inslee', 'biden'): 3,
#  ('klobuchar', 'castro', "o'rourke", 'trump'): 1,
#  ('inslee', 'delaney'): 1,
#  ('trump', 'inslee', 'sanders', 'biden'): 5,
#  ('castro',
#   'inslee',
#   'harris',
#   'warren',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('harris', 'inslee', 'sanders', 'warren'): 1,
#  ('inslee',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('inslee', 'gillibrand', 'harris', 'warren', 'trump', 'sanders', 'booker'): 2,
#  ('klobuchar', 'gillibrand', 'harris', 'sanders', 'booker'): 3,
#  ('klobuchar',
#   'inslee',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('klobuchar', 'trump', 'sanders', 'biden', "o'rourke"): 2,
#  ('klobuchar', 'inslee', 'gillibrand', 'harris', 'warren', 'trump'): 1,
#  ('klobuchar', 'trump', 'sanders', 'booker'): 1,
#  ('castro', 'trump', 'sanders', 'biden'): 8,
#  ('klobuchar',
#   'inslee',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   "o'rourke",
#   'booker'): 1,
#  ('inslee', 'harris', 'warren', 'trump', 'sanders'): 7,
#  ('harris', 'sanders', 'warren', 'booker'): 11,
#  ('castro', 'inslee', 'biden', 'trump'): 1,
#  ('klobuchar', 'sanders', 'warren', 'trump'): 4,
#  ('klobuchar', 'gabbard', 'harris', 'warren', 'trump', 'sanders', 'booker'): 1,
#  ('klobuchar',
#   'castro',
#   'inslee',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar', 'warren', 'trump', 'sanders', 'biden', 'booker'): 1,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 4,
#  ('inslee', 'gabbard', 'gillibrand', 'trump', 'sanders', 'hickenlooper'): 1,
# ...
#  ('klobuchar',
#   'castro',
#   'gabbard',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden'): 1,
#  ('klobuchar', 'inslee', 'harris', 'warren', 'sanders', 'hickenlooper'): 5,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'trump',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('warren', 'sanders', 'harris', 'yang'): 1,
#  ('harris', 'warren', 'sanders', 'biden', "o'rourke"): 2,
#  ('klobuchar', 'harris', 'trump', 'sanders', 'biden', "o'rourke"): 8,
#  ('klobuchar',
#   'inslee',
#   'castro',
#   'harris',
#   'warren',
#   'sanders',
#   'hickenlooper'): 2,
#  ('klobuchar', 'castro', 'harris', 'warren', 'williamson'): 2,
#  ('klobuchar',
#   'inslee',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'hickenlooper'): 1,
#  ('castro', 'harris', 'warren', 'sanders', 'booker'): 2,
#  ('gillibrand', 'trump', 'gabbard', 'sanders'): 6,
#  ('trump', 'williamson', 'harris', 'yang'): 3,
#  ('inslee', 'warren', 'trump', 'sanders', 'yang'): 4,
#  ('warren', 'harris', 'sanders', 'biden', "o'rourke", 'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'biden'): 4,
#  ("o'rourke", 'trump', 'buttigieg', 'harris'): 2,
#  ('klobuchar', 'gillibrand', 'warren', 'trump', 'sanders', 'biden'): 1,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar', 'trump', "o'rourke", 'warren'): 1,
#  ('trump', 'inslee', 'warren'): 7,
#  ('trump', 'sanders', 'yang'): 19,
#  ('harris', 'castro', 'warren'): 3,
#  ('harris', 'williamson', 'warren', 'sanders'): 1,
#  ('inslee', 'warren'): 1,
#  ('gillibrand', 'sanders', 'warren'): 12,
#  ('klobuchar',
#   'inslee',
#   'harris',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   "o'rourke"): 1,
#  ('castro',
#   'inslee',
#   'warren',
#   'harris',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'booker'): 2,
#  ('castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   'yang'): 2,
#  ('inslee', 'trump', 'sanders', 'hickenlooper', "o'rourke", 'booker'): 1,
#  ('gillibrand', 'harris', 'trump', 'sanders', "o'rourke", 'booker'): 2,
#  ('harris', 'trump', 'sanders', 'biden', "o'rourke"): 4,
#  ('klobuchar',
#   'inslee',
#   'castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('inslee',
#   'gillibrand',
#   'harris',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('yang',
#   'klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar',
#   'castro',
#   'inslee',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'booker'): 1,
#  ('gillibrand', 'harris', 'warren', 'trump', 'buttigieg'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 2,
#  ('klobuchar', 'trump', "o'rourke"): 1,
#  ('klobuchar', 'warren', 'harris', 'trump', 'sanders', 'biden'): 1,
#  ('klobuchar', 'warren', 'trump', 'buttigieg', 'sanders'): 4,
#  ('klobuchar',
#   'castro',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   "o'rourke"): 1,
#  ('gillibrand', 'harris', 'warren', 'trump', "o'rourke"): 2,
#  ("o'rourke", 'warren', 'sanders'): 1,
#  ('klobuchar',
#   'inslee',
#   'gabbard',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker',
#   'yang'): 1,
#  ('klobuchar',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 2,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'williamson',
#   'booker'): 1,
#  ('harris', 'warren', 'buttigieg', 'sanders', 'biden', "o'rourke"): 11,
#  ('yang', 'gabbard', 'harris', 'buttigieg', 'sanders', 'biden', 'booker'): 1,
#  ('klobuchar', 'harris', 'warren', 'trump', 'biden', "o'rourke"): 1,
#  ('yang',
#   'klobuchar',
#   'gabbard',
#   'harris',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 9,
#  ('klobuchar', 'inslee', 'sanders', 'harris'): 1,
#  ('klobuchar', 'gabbard', 'harris', 'sanders', 'yang'): 1,
#  ('gillibrand', 'gabbard', "o'rourke", 'sanders'): 1,
#  ('klobuchar', 'harris', 'trump', 'buttigieg', "o'rourke"): 2,
#  ('klobuchar', 'harris', 'trump', 'biden', 'booker'): 2,
#  ('castro', 'harris', 'trump'): 1,
#  ('klobuchar', 'inslee', 'warren', 'harris', 'trump', 'buttigieg', 'biden'): 1,
#  ('harris', 'gillibrand', 'buttigieg', 'warren'): 3,
#  ('warren', 'harris', 'trump', 'buttigieg', 'sanders', 'biden'): 16,
#  ('klobuchar', 'trump', 'biden', "o'rourke", 'booker'): 2,
#  ('harris', 'trump', "o'rourke", 'warren'): 3,
#  ('klobuchar',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'yang'): 1,
#  ('gillibrand', 'harris', 'warren', 'sanders', 'biden'): 2,
#  ('klobuchar', 'harris', 'trump', 'sanders', 'biden', "o'rourke", 'yang'): 1,
#  ('booker', 'hickenlooper'): 1,
#  ('castro', "o'rourke", 'harris', 'sanders'): 2,
#  ('gillibrand', 'trump', 'gabbard', "o'rourke"): 1,
#  ('gillibrand', 'harris', 'warren', 'trump', 'buttigieg', 'booker'): 1,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg'): 3,
#  ('inslee',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'booker',
#   'delaney'): 1,
#  ('trump', 'sanders', 'warren', 'yang'): 4,
#  ('sanders', 'warren', 'biden'): 51,
#  ('trump', 'booker', 'biden'): 6,
#  ('inslee', 'gillibrand', 'warren', 'buttigieg', 'sanders'): 1,
#  ('castro', 'warren', 'harris', 'sanders', 'williamson', 'booker'): 1,
#  ('klobuchar', 'warren', 'harris', 'sanders', "o'rourke", 'booker'): 2,
#  ('harris', 'warren', 'trump', 'buttigieg', 'yang'): 1,
#  ('castro', 'harris', 'warren', 'sanders', 'williamson', 'booker'): 3,
#  ('warren', 'trump', 'buttigieg', 'sanders', 'biden', "o'rourke"): 5,
#  ('harris', 'warren', 'trump', 'sanders', 'buttigieg'): 3,
#  ('harris', 'sanders', 'buttigieg', 'biden', 'booker'): 4,
#  ("o'rourke", 'trump', 'buttigieg', 'booker'): 2,
#  ('trump', 'buttigieg', 'warren', 'sanders'): 9,
#  ('gabbard', 'harris', 'trump', 'sanders', 'biden'): 11,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   "o'rourke",
#   'booker'): 1,
#  ('warren', 'harris', 'trump', 'sanders', 'hickenlooper', 'booker'): 2,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'warren',
#   'harris',
#   'sanders',
#   'booker'): 1,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   "o'rourke",
#   'booker'): 5,
#  ('castro',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'buttigieg',
#   'sanders'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'delaney',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'booker'): 2,
#  ('castro', 'harris', 'trump', 'hickenlooper', 'biden', 'yang'): 1,
#  ('warren', 'harris', 'sanders', 'biden', "o'rourke"): 1,
#  ('klobuchar', 'sanders', 'booker'): 1,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'booker'): 1,
#  ('castro',
#   'harris',
#   'warren',
#   'sanders',
#   'buttigieg',
#   "o'rourke",
#   'williamson',
#   'booker'): 1,
#  ('yang',
#   'klobuchar',
#   'castro',
#   'gabbard',
#   'inslee',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'booker',
#   'delaney'): 1,
#  ('warren',
#   'harris',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   "o'rourke",
#   'yang'): 2,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   'booker'): 3,
#  ('castro', "o'rourke", 'harris', 'trump'): 2,
#  ('warren', 'harris', 'trump', 'buttigieg', 'biden', 'williamson', 'yang'): 1,
#  ("o'rourke", 'sanders', 'harris', 'booker'): 1,
#  ('klobuchar',
#   'castro',
#   'inslee',
#   'gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'delaney',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('buttigieg', 'trump', 'inslee', 'sanders'): 2,
#  ('castro',
#   'gabbard',
#   'inslee',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'biden',
#   'buttigieg',
#   'sanders',
#   'delaney',
#   'booker'): 1,
#  ('klobuchar', 'gillibrand', 'harris', 'warren', 'biden'): 1,
#  ('klobuchar',
#   'inslee',
#   'castro',
#   'gillibrand',
#   'warren',
#   'buttigieg',
#   'sanders',
#   'delaney'): 1,
#  ('trump', "o'rourke", 'hickenlooper', 'biden'): 1,
#  ('booker', 'harris', 'yang'): 1,
#  ('klobuchar',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'williamson',
#   'booker'): 4,
#  ('klobuchar',
#   'inslee',
#   'warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   "o'rourke",
#   'delaney'): 1,
#  ('yang',
#   'castro',
#   'gabbard',
#   'klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'sanders',
#   'buttigieg',
#   'delaney',
#   'williamson',
#   'booker'): 1,
#  ("o'rourke", 'trump', 'buttigieg', 'sanders'): 2,
#  ('buttigieg', 'warren', 'booker'): 2,
#  ('buttigieg', 'harris', 'sanders', 'biden'): 19,
#  ("o'rourke", 'warren', 'delaney'): 2,
#  ('gillibrand', 'trump', 'delaney'): 1,
#  ('gillibrand', 'harris', 'warren', 'trump', 'buttigieg', "o'rourke"): 1,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'booker'): 1,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden',
#   "o'rourke"): 1,
#  ('warren', 'harris', 'trump', 'sanders', 'buttigieg', 'biden', 'booker'): 4,
#  ('harris', 'warren', 'buttigieg', 'sanders', 'biden', 'delaney'): 1,
#  ('inslee', 'delaney', 'biden'): 1,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'booker'): 6,
#  ('inslee', 'biden'): 6,
#  ('castro', 'warren', 'harris', 'trump', 'sanders', 'yang'): 1,
#  ('inslee',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'delaney',
#   'booker'): 1,
#  ('yang',
#   'castro',
#   'gabbard',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'williamson',
#   'booker'): 2,
#  ('trump', 'inslee', 'booker'): 1,
#  ('gillibrand', 'harris', 'trump', 'buttigieg', 'sanders'): 3,
#  ('trump', 'buttigieg', 'warren', 'booker'): 3,
#  ('gillibrand', 'sanders', 'biden'): 6,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'booker'): 4,
#  ('klobuchar',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'trump',
#   'sanders',
#   'biden',
#   'booker'): 1,
#  ('gillibrand', 'trump', 'buttigieg'): 16,
#  ("o'rourke", 'trump', 'sanders', 'warren'): 5,
#  ('castro', 'klobuchar', 'warren', 'sanders', 'booker', 'delaney'): 2,
#  ('klobuchar',
#   'gabbard',
#   'castro',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   'booker',
#   'williamson',
#   'yang'): 1,
#  ('trump', 'sanders', 'delaney'): 2,
#  ('gillibrand', 'klobuchar', 'trump', 'harris'): 1,
#  ('klobuchar', 'gillibrand', 'warren', 'trump', 'sanders', 'buttigieg'): 4,
#  ('gillibrand', 'trump', 'hickenlooper'): 1,
#  ('inslee', 'hickenlooper'): 4,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'harris',
#   'sanders',
#   'hickenlooper',
#   'booker'): 1,
#  ('yang', 'klobuchar', 'gillibrand', 'harris', 'trump', 'delaney'): 1,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 3,
#  ('klobuchar',
#   'gillibrand',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'booker'): 1,
#  ('gabbard', 'warren', 'harris', 'trump', 'buttigieg', 'sanders', 'biden'): 15,
#  ('klobuchar',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke"): 5,
#  ('warren', 'harris', 'trump', 'sanders', 'buttigieg', 'biden', "o'rourke"): 2,
#  ('buttigieg', "o'rourke", 'sanders', 'biden'): 1,
#  ('klobuchar', 'gabbard', 'warren', 'buttigieg', 'sanders', 'booker'): 13,
#  ('klobuchar',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke",
#   'booker'): 3,
#  ('harris', 'warren', 'trump', 'buttigieg', 'sanders', 'biden'): 75,
#  ('gillibrand', 'trump', 'harris', 'klobuchar'): 1,
#  ('gillibrand', 'trump', 'inslee'): 2,
#  ('warren', 'harris', 'trump', 'sanders', 'biden', "o'rourke"): 3,
#  ('gillibrand', 'trump', 'inslee', 'warren'): 2,
#  ('castro', 'trump', "o'rourke", 'harris'): 1,
#  ('gillibrand',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'hickenlooper',
#   'booker'): 2,
#  ('harris', 'warren', 'sanders', 'biden', 'booker', "o'rourke", 'yang'): 1,
#  ('trump', 'buttigieg', 'hickenlooper'): 1,
#  ('gillibrand', 'trump', 'gabbard'): 2,
#  ('klobuchar',
#   'castro',
#   'warren',
#   'trump',
#   'buttigieg',
#   'biden',
#   'delaney'): 2,
#  ('gillibrand', 'harris', 'trump', 'sanders', 'biden'): 3,
#  ('castro',
#   'klobuchar',
#   'gabbard',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'delaney',
#   'booker',
#   "o'rourke",
#   'yang'): 3,
#  ('castro', 'warren', 'biden'): 5,
#  ('klobuchar', 'sanders', 'harris', 'booker'): 3,
#  ('castro',
#   'klobuchar',
#   'gillibrand',
#   'warren',
#   'trump',
#   'booker',
#   "o'rourke",
#   'delaney'): 1,
#  ('inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'sanders',
#   'biden',
#   "o'rourke"): 2,
#  ('castro',
#   'inslee',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'hickenlooper',
#   'biden'): 1,
#  ('klobuchar', 'castro', 'warren', 'sanders', 'biden'): 6,
#  ('warren',
#   'harris',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   "o'rourke"): 12,
#  ('klobuchar', 'castro', 'warren', 'sanders', 'biden', 'delaney'): 2,
#  ('klobuchar',
#   'warren',
#   'harris',
#   'trump',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'yang'): 1,
#  ('trump', 'gabbard', 'booker', 'biden'): 1,
#  ('sanders', 'warren', 'booker', 'biden'): 1,
#  ('inslee', 'gillibrand', 'harris', 'warren', 'trump', 'sanders', 'biden'): 4,
#  ("o'rourke", 'buttigieg', 'harris', 'sanders'): 3,
#  ('castro', 'warren', 'trump', 'buttigieg', 'sanders', 'biden', 'booker'): 2,
#  ('gillibrand', 'harris', 'buttigieg', 'sanders', 'biden'): 1,
#  ('trump', 'buttigieg', 'harris', 'sanders'): 6,
#  ('yang',
#   'castro',
#   'gabbard',
#   'inslee',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'buttigieg',
#   'biden',
#   'booker'): 8,
#  ('klobuchar', 'gillibrand', 'warren', 'trump', 'sanders'): 3,
#  ("o'rourke", 'klobuchar', 'sanders', 'biden'): 2,
#  ('klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'trump',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'yang'): 2,
#  ('castro',
#   'gillibrand',
#   'warren',
#   'buttigieg',
#   'sanders',
#   'biden',
#   'yang'): 1,
#  ('castro', 'klobuchar', 'warren', 'delaney'): 1,
#  ('klobuchar', 'warren', 'biden'): 1,
#  ('castro', 'sanders', 'warren', 'biden'): 1,
#  ("o'rourke", 'buttigieg', 'sanders'): 1,
#  ('klobuchar', 'warren', 'trump', 'sanders', 'biden', "o'rourke"): 3,
#  ('gillibrand', 'warren', 'biden'): 2,
#  ('yang',
#   'castro',
#   'gabbard',
#   'inslee',
#   'klobuchar',
#   'gillibrand',
#   'harris',
#   'warren',
#   'sanders',
#   'buttigieg',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ('klobuchar', 'harris', 'trump', 'buttigieg', 'sanders', "o'rourke"): 1,
#  ('castro', 'klobuchar', 'warren', 'trump', 'sanders', 'booker'): 2,
#  ('buttigieg', 'harris', 'sanders'): 2,
#  ('klobuchar',
#   'inslee',
#   'castro',
#   'gillibrand',
#   'warren',
#   'trump',
#   'sanders',
#   'booker'): 1,
#  ('buttigieg', 'trump', 'sanders'): 35,
#  ('gillibrand', 'warren', 'harris', 'buttigieg', 'sanders'): 1,
#  ('trump', 'klobuchar', 'warren', 'biden'): 2,
#  ('buttigieg', 'sanders', 'harris'): 5,
#  ('buttigieg', 'sanders', 'harris', 'biden'): 5,
#  ('gillibrand',
#   'harris',
#   'warren',
#   'buttigieg',
#   'sanders',
#   "o'rourke",
#   'booker'): 2,
#  ('yang',
#   'klobuchar',
#   'gabbard',
#   'inslee',
#   'castro',
#   'gillibrand',
#   'harris',
#   'warren',
#   'williamson',
#   'trump',
#   'delaney',
#   'sanders',
#   'buttigieg',
#   'hickenlooper',
#   'biden',
#   "o'rourke",
#   'booker'): 1,
#  ...}
